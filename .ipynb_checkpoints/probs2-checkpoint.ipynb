# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import io
import os
from sklearn import svm
from sklearn.model_selection import cross_val_score
from mpl_toolkits import mplot3d
import idx2numpy


rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

# %%
#filepaths
file_train_images = r'./mnist/train-images.idx3-ubyte'
file_train_labels = r'./mnist/train-labels.idx1-ubyte'
file_test_images = r'./mnist/t10k-images.idx3-ubyte'
file_test_labels = r'./mnist/t10k-labels.idx1-ubyte'

train_images = idx2numpy.convert_from_file(file_train_images)
train_labels = idx2numpy.convert_from_file(file_train_labels)
test_images = idx2numpy.convert_from_file(file_test_images)
test_labels = idx2numpy.convert_from_file(file_test_labels)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 file_test_images = r'./mnist/t10k-images.idx3-ubyte'
#       5 file_test_labels = r'./mnist/t10k-labels.idx1-ubyte'
# ----> 7 train_images = idx2numpy.convert_from_file(file_train_images)
#       8 train_labels = idx2numpy.convert_from_file(file_train_labels)
#       9 test_images = idx2numpy.convert_from_file(file_test_images)
#
# File c:\Users\mark.rainey\AppData\Local\Programs\Python\Python312\Lib\site-packages\idx2numpy\converters.py:56, in convert_from_file(file)
#      50 """
#      51 Reads the content of file in IDX format, converts it into numpy.ndarray and
#      52 returns it.
#      53 file is a file-like object (with read() method) or a file name.
#      54 """
#      55 if isinstance(file, six_string_types):
# ---> 56     with open(file, 'rb') as f:
#      57         return _internal_convert(f)
#      58 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './mnist/train-images.idx3-ubyte'

# %%
m = 28**2
n = len(train_labels)

A = np.zeros((m,n))

for i in range(n):
    image = train_images[i].reshape(-1)
    A[:, i] = image

# %%
U, S, VT = np.linalg.svd(A - np.mean(A), full_matrices = False)

# %%
plt.plot(S,'-o',color='k')
plt.grid()
plt.title('Singular Value Spectrum')
plt.show()

# %%
def one_hot_encode(labels):
    """ Convert labels to one-hot encoded format """
    n_labels = len(labels)
    n_classes = 10  # As there are 10 digits in MNIST
    one_hot = np.zeros((n_classes, n_labels))
    one_hot[labels, np.arange(n_labels)] = 1
    return one_hot

B = one_hot_encode(train_labels)

# %%
mode1 = VT.T[0, :]
mode2 = VT.T[1, :]
mode3 = VT.T[2, :]

projections = np.zeros((3, n))
 
for i in range(n):
    image = A[:, i]
    projections[0, i] = np.dot(image, mode1)
    projections[1, i] = np.dot(image, mode2)
    projections[2, i] = np.dot(image, mode3)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

labelcolor = {
    0: 'white',
    1: 'red',
    2: 'orange',
    3: 'yellow',
    4: 'green',
    5: 'blue',
    6: 'purple',
    7: 'gray',
    8: 'black',  
    9: 'pink'
}
 
for i in range(projections.shape[1]): 
    x = projections[0, i]
    y = projections[1, i]
    z = projections[2, i]
    ax.scatter(x, y, z, c=labelcolor[train_labels[i]], s=12) 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
#       4 labelcolor = {
#       5     0: 'white',
#       6     1: 'red',
#    (...)
#      14     9: 'pink'
#      15 }
#
# NameError: name 'plt' is not defined

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
